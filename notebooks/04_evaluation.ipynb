# %% [markdown]
# # 📊 Stage 4: Evaluation MetricsComputes validity, uniqueness, novelty, QED, SAS, and Lipinski properties.**Prerequisites:** Stage 3 (generation) must be complete.

# %%
import os, sysCTDDG_ROOT = os.environ.get("CTDDG_ROOT", os.path.dirname(os.getcwd()))os.environ["CTDDG_ROOT"] = CTDDG_ROOTos.environ["MXNET_CUDNN_LIB_CHECKING"] = "0"os.chdir(CTDDG_ROOT)

# %% [markdown]
# ## Run Evaluation Notebook

# %%
# %%timeimport subprocessresult = subprocess.run(    [sys.executable, "-m", "jupyter", "nbconvert",     "--to", "notebook", "--execute",     "--ExecutePreprocessor.timeout=86400",     "--ExecutePreprocessor.kernel_name=ctddg_env",     f"--output=Evaluation_metrics_executed.ipynb",     os.path.join(CTDDG_ROOT, "code", "Evaluation_metrics.ipynb")],    capture_output=True, text=True, cwd=CTDDG_ROOT)if result.returncode != 0:    print("STDERR:", result.stderr[-3000:])else:    print("✅ Evaluation completed!")
